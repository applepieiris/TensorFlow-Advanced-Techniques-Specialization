# %% [markdown]
# <a href="https://colab.research.google.com/github/applepieiris/TensorFlow-Advanced-Techniques-Specialization/blob/main/Course%201%20-%20Custom%20Models%2C%20Layers%2C%20and%20Loss%20Functions%20with%20TensorFlow/Week%201/C1_W1_Lab_2_multi-output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %%
## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train.columns),))
first_dense = Dense(units=128, activation='relu')(input_layer)
second_dense = Dense(units=128, activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 8)]          0           []
#
#  dense (Dense)                  (None, 128)          1152        ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 128)          16512       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 64)           8256        ['dense_1[0][0]']
#
#  y1_output (Dense)              (None, 1)            129         ['dense_1[0][0]']
#
#  y2_output (Dense)              (None, 1)            65          ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 6ms/step - loss: 275.5240 - y1_output_loss: 124.0530 - y2_output_loss: 151.4709 - y1_output_root_mean_squared_error: 11.1379 - y2_output_root_mean_squared_error: 12.3074 - val_loss: 30.0205 - val_y1_output_loss: 16.0726 - val_y2_output_loss: 13.9479 - val_y1_output_root_mean_squared_error: 4.0091 - val_y2_output_root_mean_squared_error: 3.7347
# Epoch 2/500
# 62/62 [==============================] - 0s 2ms/step - loss: 36.5546 - y1_output_loss: 13.1982 - y2_output_loss: 23.3564 - y1_output_root_mean_squared_error: 3.6329 - y2_output_root_mean_squared_error: 4.8328 - val_loss: 18.2814 - val_y1_output_loss: 9.3422 - val_y2_output_loss: 8.9392 - val_y1_output_root_mean_squared_error: 3.0565 - val_y2_output_root_mean_squared_error: 2.9898
# Epoch 3/500
# 62/62 [==============================] - 0s 3ms/step - loss: 27.0494 - y1_output_loss: 10.4073 - y2_output_loss: 16.6421 - y1_output_root_mean_squared_error: 3.2260 - y2_output_root_mean_squared_error: 4.0795 - val_loss: 35.9764 - val_y1_output_loss: 11.3699 - val_y2_output_loss: 24.6065 - val_y1_output_root_mean_squared_error: 3.3719 - val_y2_output_root_mean_squared_error: 4.9605
# Epoch 4/500
# 62/62 [==============================] - 0s 2ms/step - loss: 25.0803 - y1_output_loss: 9.5273 - y2_output_loss: 15.5530 - y1_output_root_mean_squared_error: 3.0866 - y2_output_root_mean_squared_error: 3.9437 - val_loss: 18.3278 - val_y1_output_loss: 7.9887 - val_y2_output_loss: 10.3391 - val_y1_output_root_mean_squared_error: 2.8264 - val_y2_output_root_mean_squared_error: 3.2154
# Epoch 5/500
# 62/62 [==============================] - 0s 2ms/step - loss: 26.1511 - y1_output_loss: 9.9841 - y2_output_loss: 16.1670 - y1_output_root_mean_squared_error: 3.1598 - y2_output_root_mean_squared_error: 4.0208 - val_loss: 12.9491 - val_y1_output_loss: 6.4726 - val_y2_output_loss: 6.4765 - val_y1_output_root_mean_squared_error: 2.5441 - val_y2_output_root_mean_squared_error: 2.5449
# Epoch 6/500
# 62/62 [==============================] - 0s 2ms/step - loss: 27.0029 - y1_output_loss: 9.2577 - y2_output_loss: 17.7452 - y1_output_root_mean_squared_error: 3.0426 - y2_output_root_mean_squared_error: 4.2125 - val_loss: 16.3297 - val_y1_output_loss: 7.5161 - val_y2_output_loss: 8.8135 - val_y1_output_root_mean_squared_error: 2.7416 - val_y2_output_root_mean_squared_error: 2.9688
# Epoch 7/500
# 62/62 [==============================] - 0s 2ms/step - loss: 23.7332 - y1_output_loss: 8.8918 - y2_output_loss: 14.8415 - y1_output_root_mean_squared_error: 2.9819 - y2_output_root_mean_squared_error: 3.8525 - val_loss: 15.4370 - val_y1_output_loss: 7.7752 - val_y2_output_loss: 7.6619 - val_y1_output_root_mean_squared_error: 2.7884 - val_y2_output_root_mean_squared_error: 2.7680
# Epoch 8/500
# 62/62 [==============================] - 0s 2ms/step - loss: 21.7818 - y1_output_loss: 8.7834 - y2_output_loss: 12.9984 - y1_output_root_mean_squared_error: 2.9637 - y2_output_root_mean_squared_error: 3.6053 - val_loss: 17.9920 - val_y1_output_loss: 8.3257 - val_y2_output_loss: 9.6663 - val_y1_output_root_mean_squared_error: 2.8854 - val_y2_output_root_mean_squared_error: 3.1091
# Epoch 9/500
# 62/62 [==============================] - 0s 3ms/step - loss: 22.5186 - y1_output_loss: 8.2832 - y2_output_loss: 14.2354 - y1_output_root_mean_squared_error: 2.8781 - y2_output_root_mean_squared_error: 3.7730 - val_loss: 15.6951 - val_y1_output_loss: 7.4681 - val_y2_output_loss: 8.2270 - val_y1_output_root_mean_squared_error: 2.7328 - val_y2_output_root_mean_squared_error: 2.8683
# Epoch 10/500
# 62/62 [==============================] - 0s 2ms/step - loss: 24.3188 - y1_output_loss: 8.2129 - y2_output_loss: 16.1059 - y1_output_root_mean_squared_error: 2.8658 - y2_output_root_mean_squared_error: 4.0132 - val_loss: 24.3004 - val_y1_output_loss: 9.4074 - val_y2_output_loss: 14.8930 - val_y1_output_root_mean_squared_error: 3.0671 - val_y2_output_root_mean_squared_error: 3.8591
# Epoch 11/500
# 62/62 [==============================] - 0s 2ms/step - loss: 20.8963 - y1_output_loss: 8.2353 - y2_output_loss: 12.6610 - y1_output_root_mean_squared_error: 2.8697 - y2_output_root_mean_squared_error: 3.5582 - val_loss: 13.3214 - val_y1_output_loss: 6.9067 - val_y2_output_loss: 6.4147 - val_y1_output_root_mean_squared_error: 2.6281 - val_y2_output_root_mean_squared_error: 2.5327
# Epoch 12/500
# 62/62 [==============================] - 0s 2ms/step - loss: 23.3973 - y1_output_loss: 8.5603 - y2_output_loss: 14.8370 - y1_output_root_mean_squared_error: 2.9258 - y2_output_root_mean_squared_error: 3.8519 - val_loss: 53.0415 - val_y1_output_loss: 11.8875 - val_y2_output_loss: 41.1540 - val_y1_output_root_mean_squared_error: 3.4478 - val_y2_output_root_mean_squared_error: 6.4151
# Epoch 13/500
# 62/62 [==============================] - 0s 2ms/step - loss: 21.4883 - y1_output_loss: 7.7937 - y2_output_loss: 13.6946 - y1_output_root_mean_squared_error: 2.7917 - y2_output_root_mean_squared_error: 3.7006 - val_loss: 30.4331 - val_y1_output_loss: 10.0536 - val_y2_output_loss: 20.3794 - val_y1_output_root_mean_squared_error: 3.1707 - val_y2_output_root_mean_squared_error: 4.5144
# Epoch 14/500
# 62/62 [==============================] - 0s 2ms/step - loss: 21.9131 - y1_output_loss: 8.2683 - y2_output_loss: 13.6448 - y1_output_root_mean_squared_error: 2.8755 - y2_output_root_mean_squared_error: 3.6939 - val_loss: 40.7946 - val_y1_output_loss: 11.6335 - val_y2_output_loss: 29.1611 - val_y1_output_root_mean_squared_error: 3.4108 - val_y2_output_root_mean_squared_error: 5.4001
# Epoch 15/500
# 62/62 [==============================] - 0s 2ms/step - loss: 18.2455 - y1_output_loss: 6.7479 - y2_output_loss: 11.4976 - y1_output_root_mean_squared_error: 2.5977 - y2_output_root_mean_squared_error: 3.3908 - val_loss: 10.8889 - val_y1_output_loss: 5.6164 - val_y2_output_loss: 5.2725 - val_y1_output_root_mean_squared_error: 2.3699 - val_y2_output_root_mean_squared_error: 2.2962
# Epoch 16/500
# 62/62 [==============================] - 0s 3ms/step - loss: 18.0744 - y1_output_loss: 6.5856 - y2_output_loss: 11.4888 - y1_output_root_mean_squared_error: 2.5662 - y2_output_root_mean_squared_error: 3.3895 - val_loss: 11.8395 - val_y1_output_loss: 5.9974 - val_y2_output_loss: 5.8422 - val_y1_output_root_mean_squared_error: 2.4489 - val_y2_output_root_mean_squared_error: 2.4171
# Epoch 17/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.6746 - y1_output_loss: 5.9689 - y2_output_loss: 9.7057 - y1_output_root_mean_squared_error: 2.4431 - y2_output_root_mean_squared_error: 3.1154 - val_loss: 13.3567 - val_y1_output_loss: 5.9753 - val_y2_output_loss: 7.3814 - val_y1_output_root_mean_squared_error: 2.4444 - val_y2_output_root_mean_squared_error: 2.7169
# Epoch 18/500
# 62/62 [==============================] - 0s 2ms/step - loss: 18.2806 - y1_output_loss: 6.3717 - y2_output_loss: 11.9089 - y1_output_root_mean_squared_error: 2.5242 - y2_output_root_mean_squared_error: 3.4509 - val_loss: 23.7587 - val_y1_output_loss: 9.8302 - val_y2_output_loss: 13.9285 - val_y1_output_root_mean_squared_error: 3.1353 - val_y2_output_root_mean_squared_error: 3.7321
# Epoch 19/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.4177 - y1_output_loss: 5.6925 - y2_output_loss: 9.7252 - y1_output_root_mean_squared_error: 2.3859 - y2_output_root_mean_squared_error: 3.1185 - val_loss: 11.3807 - val_y1_output_loss: 5.9209 - val_y2_output_loss: 5.4599 - val_y1_output_root_mean_squared_error: 2.4333 - val_y2_output_root_mean_squared_error: 2.3366
# Epoch 20/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.0800 - y1_output_loss: 5.3929 - y2_output_loss: 9.6871 - y1_output_root_mean_squared_error: 2.3223 - y2_output_root_mean_squared_error: 3.1124 - val_loss: 30.4695 - val_y1_output_loss: 8.7872 - val_y2_output_loss: 21.6823 - val_y1_output_root_mean_squared_error: 2.9643 - val_y2_output_root_mean_squared_error: 4.6564
# Epoch 21/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.1739 - y1_output_loss: 5.4404 - y2_output_loss: 9.7334 - y1_output_root_mean_squared_error: 2.3325 - y2_output_root_mean_squared_error: 3.1198 - val_loss: 12.2920 - val_y1_output_loss: 5.7675 - val_y2_output_loss: 6.5245 - val_y1_output_root_mean_squared_error: 2.4016 - val_y2_output_root_mean_squared_error: 2.5543
# Epoch 22/500
# 62/62 [==============================] - 0s 2ms/step - loss: 13.9465 - y1_output_loss: 5.3299 - y2_output_loss: 8.6167 - y1_output_root_mean_squared_error: 2.3087 - y2_output_root_mean_squared_error: 2.9354 - val_loss: 27.3845 - val_y1_output_loss: 7.8530 - val_y2_output_loss: 19.5315 - val_y1_output_root_mean_squared_error: 2.8023 - val_y2_output_root_mean_squared_error: 4.4194
# Epoch 23/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.6887 - y1_output_loss: 4.5482 - y2_output_loss: 7.1406 - y1_output_root_mean_squared_error: 2.1326 - y2_output_root_mean_squared_error: 2.6722 - val_loss: 7.6178 - val_y1_output_loss: 3.3917 - val_y2_output_loss: 4.2260 - val_y1_output_root_mean_squared_error: 1.8417 - val_y2_output_root_mean_squared_error: 2.0557
# Epoch 24/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.2351 - y1_output_loss: 4.3739 - y2_output_loss: 7.8611 - y1_output_root_mean_squared_error: 2.0914 - y2_output_root_mean_squared_error: 2.8038 - val_loss: 12.7487 - val_y1_output_loss: 3.7957 - val_y2_output_loss: 8.9531 - val_y1_output_root_mean_squared_error: 1.9482 - val_y2_output_root_mean_squared_error: 2.9922
# Epoch 25/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.6433 - y1_output_loss: 3.8637 - y2_output_loss: 6.7796 - y1_output_root_mean_squared_error: 1.9656 - y2_output_root_mean_squared_error: 2.6038 - val_loss: 7.7587 - val_y1_output_loss: 2.9888 - val_y2_output_loss: 4.7699 - val_y1_output_root_mean_squared_error: 1.7288 - val_y2_output_root_mean_squared_error: 2.1840
# Epoch 26/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.1361 - y1_output_loss: 3.4630 - y2_output_loss: 5.6731 - y1_output_root_mean_squared_error: 1.8609 - y2_output_root_mean_squared_error: 2.3818 - val_loss: 7.3928 - val_y1_output_loss: 2.9057 - val_y2_output_loss: 4.4871 - val_y1_output_root_mean_squared_error: 1.7046 - val_y2_output_root_mean_squared_error: 2.1183
# Epoch 27/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.9756 - y1_output_loss: 3.8946 - y2_output_loss: 8.0810 - y1_output_root_mean_squared_error: 1.9735 - y2_output_root_mean_squared_error: 2.8427 - val_loss: 14.4258 - val_y1_output_loss: 5.9518 - val_y2_output_loss: 8.4740 - val_y1_output_root_mean_squared_error: 2.4396 - val_y2_output_root_mean_squared_error: 2.9110
# Epoch 28/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.6470 - y1_output_loss: 3.4964 - y2_output_loss: 6.1506 - y1_output_root_mean_squared_error: 1.8699 - y2_output_root_mean_squared_error: 2.4800 - val_loss: 6.5014 - val_y1_output_loss: 2.7385 - val_y2_output_loss: 3.7629 - val_y1_output_root_mean_squared_error: 1.6548 - val_y2_output_root_mean_squared_error: 1.9398
# Epoch 29/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.3520 - y1_output_loss: 3.3273 - y2_output_loss: 6.0247 - y1_output_root_mean_squared_error: 1.8241 - y2_output_root_mean_squared_error: 2.4545 - val_loss: 8.0083 - val_y1_output_loss: 3.6779 - val_y2_output_loss: 4.3304 - val_y1_output_root_mean_squared_error: 1.9178 - val_y2_output_root_mean_squared_error: 2.0810
# Epoch 30/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.4011 - y1_output_loss: 3.6911 - y2_output_loss: 6.7100 - y1_output_root_mean_squared_error: 1.9212 - y2_output_root_mean_squared_error: 2.5904 - val_loss: 9.0984 - val_y1_output_loss: 3.7939 - val_y2_output_loss: 5.3045 - val_y1_output_root_mean_squared_error: 1.9478 - val_y2_output_root_mean_squared_error: 2.3031
# Epoch 31/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.2719 - y1_output_loss: 3.4488 - y2_output_loss: 6.8231 - y1_output_root_mean_squared_error: 1.8571 - y2_output_root_mean_squared_error: 2.6121 - val_loss: 8.4745 - val_y1_output_loss: 3.4527 - val_y2_output_loss: 5.0219 - val_y1_output_root_mean_squared_error: 1.8581 - val_y2_output_root_mean_squared_error: 2.2409
# Epoch 32/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.2295 - y1_output_loss: 2.9081 - y2_output_loss: 5.3214 - y1_output_root_mean_squared_error: 1.7053 - y2_output_root_mean_squared_error: 2.3068 - val_loss: 6.9298 - val_y1_output_loss: 2.4579 - val_y2_output_loss: 4.4720 - val_y1_output_root_mean_squared_error: 1.5678 - val_y2_output_root_mean_squared_error: 2.1147
# Epoch 33/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.9580 - y1_output_loss: 3.2168 - y2_output_loss: 6.7413 - y1_output_root_mean_squared_error: 1.7935 - y2_output_root_mean_squared_error: 2.5964 - val_loss: 9.3444 - val_y1_output_loss: 3.2141 - val_y2_output_loss: 6.1303 - val_y1_output_root_mean_squared_error: 1.7928 - val_y2_output_root_mean_squared_error: 2.4759
# Epoch 34/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.3436 - y1_output_loss: 3.2265 - y2_output_loss: 7.1170 - y1_output_root_mean_squared_error: 1.7963 - y2_output_root_mean_squared_error: 2.6678 - val_loss: 13.1415 - val_y1_output_loss: 3.0236 - val_y2_output_loss: 10.1179 - val_y1_output_root_mean_squared_error: 1.7389 - val_y2_output_root_mean_squared_error: 3.1809
# Epoch 35/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.1798 - y1_output_loss: 2.9622 - y2_output_loss: 6.2176 - y1_output_root_mean_squared_error: 1.7211 - y2_output_root_mean_squared_error: 2.4935 - val_loss: 6.4007 - val_y1_output_loss: 2.3829 - val_y2_output_loss: 4.0178 - val_y1_output_root_mean_squared_error: 1.5437 - val_y2_output_root_mean_squared_error: 2.0044
# Epoch 36/500
# 62/62 [==============================] - 0s 5ms/step - loss: 7.2312 - y1_output_loss: 2.4443 - y2_output_loss: 4.7870 - y1_output_root_mean_squared_error: 1.5634 - y2_output_root_mean_squared_error: 2.1879 - val_loss: 14.7186 - val_y1_output_loss: 6.1754 - val_y2_output_loss: 8.5432 - val_y1_output_root_mean_squared_error: 2.4850 - val_y2_output_root_mean_squared_error: 2.9229
# Epoch 37/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.9442 - y1_output_loss: 2.7577 - y2_output_loss: 6.1866 - y1_output_root_mean_squared_error: 1.6606 - y2_output_root_mean_squared_error: 2.4873 - val_loss: 12.4960 - val_y1_output_loss: 3.8645 - val_y2_output_loss: 8.6315 - val_y1_output_root_mean_squared_error: 1.9658 - val_y2_output_root_mean_squared_error: 2.9379
# Epoch 38/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.9469 - y1_output_loss: 2.3335 - y2_output_loss: 4.6133 - y1_output_root_mean_squared_error: 1.5276 - y2_output_root_mean_squared_error: 2.1479 - val_loss: 9.5411 - val_y1_output_loss: 2.9926 - val_y2_output_loss: 6.5485 - val_y1_output_root_mean_squared_error: 1.7299 - val_y2_output_root_mean_squared_error: 2.5590
# Epoch 39/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.1172 - y1_output_loss: 2.3632 - y2_output_loss: 4.7540 - y1_output_root_mean_squared_error: 1.5373 - y2_output_root_mean_squared_error: 2.1804 - val_loss: 6.8440 - val_y1_output_loss: 2.3473 - val_y2_output_loss: 4.4967 - val_y1_output_root_mean_squared_error: 1.5321 - val_y2_output_root_mean_squared_error: 2.1205
# Epoch 40/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.9615 - y1_output_loss: 2.3485 - y2_output_loss: 4.6130 - y1_output_root_mean_squared_error: 1.5325 - y2_output_root_mean_squared_error: 2.1478 - val_loss: 7.2229 - val_y1_output_loss: 2.4030 - val_y2_output_loss: 4.8199 - val_y1_output_root_mean_squared_error: 1.5502 - val_y2_output_root_mean_squared_error: 2.1954
# Epoch 41/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.8574 - y1_output_loss: 2.6632 - y2_output_loss: 6.1942 - y1_output_root_mean_squared_error: 1.6319 - y2_output_root_mean_squared_error: 2.4888 - val_loss: 7.8581 - val_y1_output_loss: 3.3988 - val_y2_output_loss: 4.4593 - val_y1_output_root_mean_squared_error: 1.8436 - val_y2_output_root_mean_squared_error: 2.1117
# Epoch 42/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.6951 - y1_output_loss: 2.2280 - y2_output_loss: 5.4671 - y1_output_root_mean_squared_error: 1.4926 - y2_output_root_mean_squared_error: 2.3382 - val_loss: 7.3246 - val_y1_output_loss: 2.9289 - val_y2_output_loss: 4.3957 - val_y1_output_root_mean_squared_error: 1.7114 - val_y2_output_root_mean_squared_error: 2.0966
# Epoch 43/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.3200 - y1_output_loss: 2.5306 - y2_output_loss: 5.7894 - y1_output_root_mean_squared_error: 1.5908 - y2_output_root_mean_squared_error: 2.4061 - val_loss: 7.9654 - val_y1_output_loss: 3.1999 - val_y2_output_loss: 4.7656 - val_y1_output_root_mean_squared_error: 1.7888 - val_y2_output_root_mean_squared_error: 2.1830
# Epoch 44/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.8944 - y1_output_loss: 1.9844 - y2_output_loss: 3.9100 - y1_output_root_mean_squared_error: 1.4087 - y2_output_root_mean_squared_error: 1.9774 - val_loss: 12.2655 - val_y1_output_loss: 3.0832 - val_y2_output_loss: 9.1823 - val_y1_output_root_mean_squared_error: 1.7559 - val_y2_output_root_mean_squared_error: 3.0302
# Epoch 45/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.6746 - y1_output_loss: 1.9677 - y2_output_loss: 4.7069 - y1_output_root_mean_squared_error: 1.4027 - y2_output_root_mean_squared_error: 2.1695 - val_loss: 6.3820 - val_y1_output_loss: 2.3509 - val_y2_output_loss: 4.0312 - val_y1_output_root_mean_squared_error: 1.5332 - val_y2_output_root_mean_squared_error: 2.0078
# Epoch 46/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.6577 - y1_output_loss: 2.4302 - y2_output_loss: 5.2275 - y1_output_root_mean_squared_error: 1.5589 - y2_output_root_mean_squared_error: 2.2864 - val_loss: 6.4610 - val_y1_output_loss: 2.7677 - val_y2_output_loss: 3.6933 - val_y1_output_root_mean_squared_error: 1.6636 - val_y2_output_root_mean_squared_error: 1.9218
# Epoch 47/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.0020 - y1_output_loss: 2.2457 - y2_output_loss: 4.7562 - y1_output_root_mean_squared_error: 1.4986 - y2_output_root_mean_squared_error: 2.1809 - val_loss: 13.2129 - val_y1_output_loss: 3.7228 - val_y2_output_loss: 9.4901 - val_y1_output_root_mean_squared_error: 1.9294 - val_y2_output_root_mean_squared_error: 3.0806
# Epoch 48/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.5287 - y1_output_loss: 2.4017 - y2_output_loss: 6.1270 - y1_output_root_mean_squared_error: 1.5497 - y2_output_root_mean_squared_error: 2.4753 - val_loss: 41.7480 - val_y1_output_loss: 8.6236 - val_y2_output_loss: 33.1244 - val_y1_output_root_mean_squared_error: 2.9366 - val_y2_output_root_mean_squared_error: 5.7554
# Epoch 49/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.2179 - y1_output_loss: 2.7650 - y2_output_loss: 6.4530 - y1_output_root_mean_squared_error: 1.6628 - y2_output_root_mean_squared_error: 2.5403 - val_loss: 5.4520 - val_y1_output_loss: 1.8527 - val_y2_output_loss: 3.5993 - val_y1_output_root_mean_squared_error: 1.3611 - val_y2_output_root_mean_squared_error: 1.8972
# Epoch 50/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.9209 - y1_output_loss: 1.8138 - y2_output_loss: 4.1071 - y1_output_root_mean_squared_error: 1.3468 - y2_output_root_mean_squared_error: 2.0266 - val_loss: 18.4662 - val_y1_output_loss: 6.4303 - val_y2_output_loss: 12.0359 - val_y1_output_root_mean_squared_error: 2.5358 - val_y2_output_root_mean_squared_error: 3.4693
# Epoch 51/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.1435 - y1_output_loss: 1.9626 - y2_output_loss: 4.1809 - y1_output_root_mean_squared_error: 1.4009 - y2_output_root_mean_squared_error: 2.0447 - val_loss: 10.1407 - val_y1_output_loss: 2.3998 - val_y2_output_loss: 7.7409 - val_y1_output_root_mean_squared_error: 1.5491 - val_y2_output_root_mean_squared_error: 2.7822
# Epoch 52/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.3428 - y1_output_loss: 1.6471 - y2_output_loss: 3.6957 - y1_output_root_mean_squared_error: 1.2834 - y2_output_root_mean_squared_error: 1.9224 - val_loss: 9.6533 - val_y1_output_loss: 2.3184 - val_y2_output_loss: 7.3349 - val_y1_output_root_mean_squared_error: 1.5226 - val_y2_output_root_mean_squared_error: 2.7083
# Epoch 53/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.1616 - y1_output_loss: 2.1542 - y2_output_loss: 5.0074 - y1_output_root_mean_squared_error: 1.4677 - y2_output_root_mean_squared_error: 2.2377 - val_loss: 5.7284 - val_y1_output_loss: 2.0810 - val_y2_output_loss: 3.6473 - val_y1_output_root_mean_squared_error: 1.4426 - val_y2_output_root_mean_squared_error: 1.9098
# Epoch 54/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.5428 - y1_output_loss: 1.9363 - y2_output_loss: 4.6065 - y1_output_root_mean_squared_error: 1.3915 - y2_output_root_mean_squared_error: 2.1463 - val_loss: 12.4704 - val_y1_output_loss: 3.3973 - val_y2_output_loss: 9.0731 - val_y1_output_root_mean_squared_error: 1.8432 - val_y2_output_root_mean_squared_error: 3.0122
# Epoch 55/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.7370 - y1_output_loss: 1.7257 - y2_output_loss: 4.0114 - y1_output_root_mean_squared_error: 1.3137 - y2_output_root_mean_squared_error: 2.0028 - val_loss: 8.1386 - val_y1_output_loss: 2.9366 - val_y2_output_loss: 5.2020 - val_y1_output_root_mean_squared_error: 1.7136 - val_y2_output_root_mean_squared_error: 2.2808
# Epoch 56/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.8537 - y1_output_loss: 2.2956 - y2_output_loss: 5.5581 - y1_output_root_mean_squared_error: 1.5151 - y2_output_root_mean_squared_error: 2.3576 - val_loss: 6.5096 - val_y1_output_loss: 1.7527 - val_y2_output_loss: 4.7570 - val_y1_output_root_mean_squared_error: 1.3239 - val_y2_output_root_mean_squared_error: 2.1810
# Epoch 57/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.7923 - y1_output_loss: 1.7677 - y2_output_loss: 4.0246 - y1_output_root_mean_squared_error: 1.3295 - y2_output_root_mean_squared_error: 2.0061 - val_loss: 4.1251 - val_y1_output_loss: 1.4227 - val_y2_output_loss: 2.7024 - val_y1_output_root_mean_squared_error: 1.1928 - val_y2_output_root_mean_squared_error: 1.6439
# Epoch 58/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.4843 - y1_output_loss: 1.6308 - y2_output_loss: 3.8535 - y1_output_root_mean_squared_error: 1.2770 - y2_output_root_mean_squared_error: 1.9630 - val_loss: 4.3180 - val_y1_output_loss: 1.4984 - val_y2_output_loss: 2.8196 - val_y1_output_root_mean_squared_error: 1.2241 - val_y2_output_root_mean_squared_error: 1.6792
# Epoch 59/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.5421 - y1_output_loss: 1.4929 - y2_output_loss: 3.0492 - y1_output_root_mean_squared_error: 1.2218 - y2_output_root_mean_squared_error: 1.7462 - val_loss: 6.5890 - val_y1_output_loss: 1.6537 - val_y2_output_loss: 4.9352 - val_y1_output_root_mean_squared_error: 1.2860 - val_y2_output_root_mean_squared_error: 2.2215
# Epoch 60/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.5670 - y1_output_loss: 1.7657 - y2_output_loss: 4.8013 - y1_output_root_mean_squared_error: 1.3288 - y2_output_root_mean_squared_error: 2.1912 - val_loss: 15.1244 - val_y1_output_loss: 2.2376 - val_y2_output_loss: 12.8868 - val_y1_output_root_mean_squared_error: 1.4959 - val_y2_output_root_mean_squared_error: 3.5898
# Epoch 61/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.9508 - y1_output_loss: 1.5820 - y2_output_loss: 3.3688 - y1_output_root_mean_squared_error: 1.2578 - y2_output_root_mean_squared_error: 1.8354 - val_loss: 4.9108 - val_y1_output_loss: 1.3724 - val_y2_output_loss: 3.5385 - val_y1_output_root_mean_squared_error: 1.1715 - val_y2_output_root_mean_squared_error: 1.8811
# Epoch 62/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.6511 - y1_output_loss: 1.5164 - y2_output_loss: 3.1347 - y1_output_root_mean_squared_error: 1.2314 - y2_output_root_mean_squared_error: 1.7705 - val_loss: 4.5054 - val_y1_output_loss: 1.6114 - val_y2_output_loss: 2.8941 - val_y1_output_root_mean_squared_error: 1.2694 - val_y2_output_root_mean_squared_error: 1.7012
# Epoch 63/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.0923 - y1_output_loss: 1.6059 - y2_output_loss: 4.4864 - y1_output_root_mean_squared_error: 1.2672 - y2_output_root_mean_squared_error: 2.1181 - val_loss: 10.2572 - val_y1_output_loss: 2.6948 - val_y2_output_loss: 7.5624 - val_y1_output_root_mean_squared_error: 1.6416 - val_y2_output_root_mean_squared_error: 2.7500
# Epoch 64/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.7680 - y1_output_loss: 1.6442 - y2_output_loss: 4.1238 - y1_output_root_mean_squared_error: 1.2823 - y2_output_root_mean_squared_error: 2.0307 - val_loss: 3.8383 - val_y1_output_loss: 1.1653 - val_y2_output_loss: 2.6730 - val_y1_output_root_mean_squared_error: 1.0795 - val_y2_output_root_mean_squared_error: 1.6349
# Epoch 65/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.6064 - y1_output_loss: 1.5855 - y2_output_loss: 4.0209 - y1_output_root_mean_squared_error: 1.2592 - y2_output_root_mean_squared_error: 2.0052 - val_loss: 4.3983 - val_y1_output_loss: 1.4085 - val_y2_output_loss: 2.9897 - val_y1_output_root_mean_squared_error: 1.1868 - val_y2_output_root_mean_squared_error: 1.7291
# Epoch 66/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.7180 - y1_output_loss: 1.9497 - y2_output_loss: 3.7683 - y1_output_root_mean_squared_error: 1.3963 - y2_output_root_mean_squared_error: 1.9412 - val_loss: 6.3781 - val_y1_output_loss: 2.3306 - val_y2_output_loss: 4.0475 - val_y1_output_root_mean_squared_error: 1.5266 - val_y2_output_root_mean_squared_error: 2.0118
# Epoch 67/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.0695 - y1_output_loss: 1.4779 - y2_output_loss: 3.5917 - y1_output_root_mean_squared_error: 1.2157 - y2_output_root_mean_squared_error: 1.8952 - val_loss: 25.8206 - val_y1_output_loss: 7.3254 - val_y2_output_loss: 18.4952 - val_y1_output_root_mean_squared_error: 2.7066 - val_y2_output_root_mean_squared_error: 4.3006
# Epoch 68/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.5884 - y1_output_loss: 1.5876 - y2_output_loss: 4.0008 - y1_output_root_mean_squared_error: 1.2600 - y2_output_root_mean_squared_error: 2.0002 - val_loss: 3.5285 - val_y1_output_loss: 1.0732 - val_y2_output_loss: 2.4553 - val_y1_output_root_mean_squared_error: 1.0360 - val_y2_output_root_mean_squared_error: 1.5669
# Epoch 69/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.3955 - y1_output_loss: 1.4249 - y2_output_loss: 2.9706 - y1_output_root_mean_squared_error: 1.1937 - y2_output_root_mean_squared_error: 1.7235 - val_loss: 6.4685 - val_y1_output_loss: 1.0487 - val_y2_output_loss: 5.4198 - val_y1_output_root_mean_squared_error: 1.0241 - val_y2_output_root_mean_squared_error: 2.3280
# Epoch 70/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.2320 - y1_output_loss: 1.3550 - y2_output_loss: 3.8770 - y1_output_root_mean_squared_error: 1.1640 - y2_output_root_mean_squared_error: 1.9690 - val_loss: 3.5292 - val_y1_output_loss: 1.1972 - val_y2_output_loss: 2.3320 - val_y1_output_root_mean_squared_error: 1.0942 - val_y2_output_root_mean_squared_error: 1.5271
# Epoch 71/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.1111 - y1_output_loss: 1.2112 - y2_output_loss: 2.8998 - y1_output_root_mean_squared_error: 1.1006 - y2_output_root_mean_squared_error: 1.7029 - val_loss: 11.4894 - val_y1_output_loss: 3.3561 - val_y2_output_loss: 8.1333 - val_y1_output_root_mean_squared_error: 1.8320 - val_y2_output_root_mean_squared_error: 2.8519
# Epoch 72/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.7538 - y1_output_loss: 1.4350 - y2_output_loss: 3.3188 - y1_output_root_mean_squared_error: 1.1979 - y2_output_root_mean_squared_error: 1.8218 - val_loss: 5.3317 - val_y1_output_loss: 1.6309 - val_y2_output_loss: 3.7008 - val_y1_output_root_mean_squared_error: 1.2771 - val_y2_output_root_mean_squared_error: 1.9238
# Epoch 73/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.0633 - y1_output_loss: 1.1094 - y2_output_loss: 2.9540 - y1_output_root_mean_squared_error: 1.0533 - y2_output_root_mean_squared_error: 1.7187 - val_loss: 6.9642 - val_y1_output_loss: 1.2216 - val_y2_output_loss: 5.7425 - val_y1_output_root_mean_squared_error: 1.1053 - val_y2_output_root_mean_squared_error: 2.3964
# Epoch 74/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.7612 - y1_output_loss: 1.0613 - y2_output_loss: 2.6999 - y1_output_root_mean_squared_error: 1.0302 - y2_output_root_mean_squared_error: 1.6432 - val_loss: 3.8538 - val_y1_output_loss: 0.9399 - val_y2_output_loss: 2.9139 - val_y1_output_root_mean_squared_error: 0.9695 - val_y2_output_root_mean_squared_error: 1.7070
# Epoch 75/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.8582 - y1_output_loss: 1.3211 - y2_output_loss: 3.5371 - y1_output_root_mean_squared_error: 1.1494 - y2_output_root_mean_squared_error: 1.8807 - val_loss: 4.6673 - val_y1_output_loss: 1.1604 - val_y2_output_loss: 3.5069 - val_y1_output_root_mean_squared_error: 1.0772 - val_y2_output_root_mean_squared_error: 1.8727
# Epoch 76/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.4988 - y1_output_loss: 0.9646 - y2_output_loss: 2.5342 - y1_output_root_mean_squared_error: 0.9821 - y2_output_root_mean_squared_error: 1.5919 - val_loss: 9.1571 - val_y1_output_loss: 3.0166 - val_y2_output_loss: 6.1405 - val_y1_output_root_mean_squared_error: 1.7368 - val_y2_output_root_mean_squared_error: 2.4780
# Epoch 77/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.5616 - y1_output_loss: 1.4093 - y2_output_loss: 3.1522 - y1_output_root_mean_squared_error: 1.1872 - y2_output_root_mean_squared_error: 1.7754 - val_loss: 12.0727 - val_y1_output_loss: 4.7655 - val_y2_output_loss: 7.3072 - val_y1_output_root_mean_squared_error: 2.1830 - val_y2_output_root_mean_squared_error: 2.7032
# Epoch 78/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.8155 - y1_output_loss: 1.0239 - y2_output_loss: 2.7917 - y1_output_root_mean_squared_error: 1.0119 - y2_output_root_mean_squared_error: 1.6708 - val_loss: 3.6971 - val_y1_output_loss: 0.9229 - val_y2_output_loss: 2.7742 - val_y1_output_root_mean_squared_error: 0.9607 - val_y2_output_root_mean_squared_error: 1.6656
# Epoch 79/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.5478 - y1_output_loss: 0.9538 - y2_output_loss: 2.5940 - y1_output_root_mean_squared_error: 0.9766 - y2_output_root_mean_squared_error: 1.6106 - val_loss: 3.0865 - val_y1_output_loss: 0.8068 - val_y2_output_loss: 2.2797 - val_y1_output_root_mean_squared_error: 0.8982 - val_y2_output_root_mean_squared_error: 1.5099
# Epoch 80/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.0262 - y1_output_loss: 1.0671 - y2_output_loss: 2.9591 - y1_output_root_mean_squared_error: 1.0330 - y2_output_root_mean_squared_error: 1.7202 - val_loss: 3.2875 - val_y1_output_loss: 0.7505 - val_y2_output_loss: 2.5370 - val_y1_output_root_mean_squared_error: 0.8663 - val_y2_output_root_mean_squared_error: 1.5928
# Epoch 81/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.0968 - y1_output_loss: 1.1395 - y2_output_loss: 2.9573 - y1_output_root_mean_squared_error: 1.0675 - y2_output_root_mean_squared_error: 1.7197 - val_loss: 4.4976 - val_y1_output_loss: 1.7954 - val_y2_output_loss: 2.7022 - val_y1_output_root_mean_squared_error: 1.3399 - val_y2_output_root_mean_squared_error: 1.6438
# Epoch 82/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.2334 - y1_output_loss: 1.1858 - y2_output_loss: 3.0476 - y1_output_root_mean_squared_error: 1.0890 - y2_output_root_mean_squared_error: 1.7457 - val_loss: 7.3051 - val_y1_output_loss: 2.4472 - val_y2_output_loss: 4.8579 - val_y1_output_root_mean_squared_error: 1.5644 - val_y2_output_root_mean_squared_error: 2.2041
# Epoch 83/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.8312 - y1_output_loss: 1.3103 - y2_output_loss: 3.5209 - y1_output_root_mean_squared_error: 1.1447 - y2_output_root_mean_squared_error: 1.8764 - val_loss: 27.0962 - val_y1_output_loss: 10.1996 - val_y2_output_loss: 16.8965 - val_y1_output_root_mean_squared_error: 3.1937 - val_y2_output_root_mean_squared_error: 4.1105
# Epoch 84/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.4986 - y1_output_loss: 1.2281 - y2_output_loss: 3.2704 - y1_output_root_mean_squared_error: 1.1082 - y2_output_root_mean_squared_error: 1.8084 - val_loss: 15.8401 - val_y1_output_loss: 7.1191 - val_y2_output_loss: 8.7209 - val_y1_output_root_mean_squared_error: 2.6682 - val_y2_output_root_mean_squared_error: 2.9531
# Epoch 85/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.2325 - y1_output_loss: 0.9542 - y2_output_loss: 2.2783 - y1_output_root_mean_squared_error: 0.9768 - y2_output_root_mean_squared_error: 1.5094 - val_loss: 8.8013 - val_y1_output_loss: 2.5464 - val_y2_output_loss: 6.2549 - val_y1_output_root_mean_squared_error: 1.5958 - val_y2_output_root_mean_squared_error: 2.5010
# Epoch 86/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.3945 - y1_output_loss: 1.1752 - y2_output_loss: 4.2193 - y1_output_root_mean_squared_error: 1.0840 - y2_output_root_mean_squared_error: 2.0541 - val_loss: 10.2669 - val_y1_output_loss: 4.1313 - val_y2_output_loss: 6.1357 - val_y1_output_root_mean_squared_error: 2.0326 - val_y2_output_root_mean_squared_error: 2.4770
# Epoch 87/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.6237 - y1_output_loss: 0.9987 - y2_output_loss: 2.6249 - y1_output_root_mean_squared_error: 0.9994 - y2_output_root_mean_squared_error: 1.6202 - val_loss: 15.9003 - val_y1_output_loss: 5.8635 - val_y2_output_loss: 10.0368 - val_y1_output_root_mean_squared_error: 2.4215 - val_y2_output_root_mean_squared_error: 3.1681
# Epoch 88/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.9807 - y1_output_loss: 0.8402 - y2_output_loss: 2.1404 - y1_output_root_mean_squared_error: 0.9166 - y2_output_root_mean_squared_error: 1.4630 - val_loss: 5.9697 - val_y1_output_loss: 1.2462 - val_y2_output_loss: 4.7235 - val_y1_output_root_mean_squared_error: 1.1163 - val_y2_output_root_mean_squared_error: 2.1734
# Epoch 89/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.3546 - y1_output_loss: 1.8458 - y2_output_loss: 4.5088 - y1_output_root_mean_squared_error: 1.3586 - y2_output_root_mean_squared_error: 2.1234 - val_loss: 3.1320 - val_y1_output_loss: 0.6946 - val_y2_output_loss: 2.4374 - val_y1_output_root_mean_squared_error: 0.8334 - val_y2_output_root_mean_squared_error: 1.5612
# Epoch 90/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.1949 - y1_output_loss: 0.7924 - y2_output_loss: 2.4025 - y1_output_root_mean_squared_error: 0.8902 - y2_output_root_mean_squared_error: 1.5500 - val_loss: 3.2631 - val_y1_output_loss: 0.9918 - val_y2_output_loss: 2.2714 - val_y1_output_root_mean_squared_error: 0.9959 - val_y2_output_root_mean_squared_error: 1.5071
# Epoch 91/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.2585 - y1_output_loss: 0.8868 - y2_output_loss: 2.3717 - y1_output_root_mean_squared_error: 0.9417 - y2_output_root_mean_squared_error: 1.5400 - val_loss: 12.2832 - val_y1_output_loss: 3.6415 - val_y2_output_loss: 8.6417 - val_y1_output_root_mean_squared_error: 1.9083 - val_y2_output_root_mean_squared_error: 2.9397
# Epoch 92/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.8037 - y1_output_loss: 1.1871 - y2_output_loss: 3.6165 - y1_output_root_mean_squared_error: 1.0895 - y2_output_root_mean_squared_error: 1.9017 - val_loss: 2.6311 - val_y1_output_loss: 0.7281 - val_y2_output_loss: 1.9030 - val_y1_output_root_mean_squared_error: 0.8533 - val_y2_output_root_mean_squared_error: 1.3795
# Epoch 93/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.3043 - y1_output_loss: 0.8359 - y2_output_loss: 2.4684 - y1_output_root_mean_squared_error: 0.9143 - y2_output_root_mean_squared_error: 1.5711 - val_loss: 3.8669 - val_y1_output_loss: 0.8782 - val_y2_output_loss: 2.9887 - val_y1_output_root_mean_squared_error: 0.9371 - val_y2_output_root_mean_squared_error: 1.7288
# Epoch 94/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.3680 - y1_output_loss: 0.8828 - y2_output_loss: 2.4852 - y1_output_root_mean_squared_error: 0.9396 - y2_output_root_mean_squared_error: 1.5764 - val_loss: 2.7202 - val_y1_output_loss: 0.8292 - val_y2_output_loss: 1.8910 - val_y1_output_root_mean_squared_error: 0.9106 - val_y2_output_root_mean_squared_error: 1.3751
# Epoch 95/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.3563 - y1_output_loss: 0.8748 - y2_output_loss: 2.4815 - y1_output_root_mean_squared_error: 0.9353 - y2_output_root_mean_squared_error: 1.5753 - val_loss: 3.6434 - val_y1_output_loss: 0.5833 - val_y2_output_loss: 3.0600 - val_y1_output_root_mean_squared_error: 0.7638 - val_y2_output_root_mean_squared_error: 1.7493
# Epoch 96/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.7261 - y1_output_loss: 1.4102 - y2_output_loss: 3.3159 - y1_output_root_mean_squared_error: 1.1875 - y2_output_root_mean_squared_error: 1.8210 - val_loss: 2.2696 - val_y1_output_loss: 0.6664 - val_y2_output_loss: 1.6032 - val_y1_output_root_mean_squared_error: 0.8163 - val_y2_output_root_mean_squared_error: 1.2662
# Epoch 97/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8351 - y1_output_loss: 0.6642 - y2_output_loss: 2.1709 - y1_output_root_mean_squared_error: 0.8150 - y2_output_root_mean_squared_error: 1.4734 - val_loss: 2.5428 - val_y1_output_loss: 0.6274 - val_y2_output_loss: 1.9154 - val_y1_output_root_mean_squared_error: 0.7921 - val_y2_output_root_mean_squared_error: 1.3840
# Epoch 98/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.4441 - y1_output_loss: 0.8948 - y2_output_loss: 2.5493 - y1_output_root_mean_squared_error: 0.9459 - y2_output_root_mean_squared_error: 1.5967 - val_loss: 6.4320 - val_y1_output_loss: 2.3419 - val_y2_output_loss: 4.0902 - val_y1_output_root_mean_squared_error: 1.5303 - val_y2_output_root_mean_squared_error: 2.0224
# Epoch 99/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.8619 - y1_output_loss: 0.7678 - y2_output_loss: 2.0941 - y1_output_root_mean_squared_error: 0.8763 - y2_output_root_mean_squared_error: 1.4471 - val_loss: 61.5940 - val_y1_output_loss: 13.6004 - val_y2_output_loss: 47.9937 - val_y1_output_root_mean_squared_error: 3.6879 - val_y2_output_root_mean_squared_error: 6.9277
# Epoch 100/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.3869 - y1_output_loss: 1.2647 - y2_output_loss: 4.1222 - y1_output_root_mean_squared_error: 1.1246 - y2_output_root_mean_squared_error: 2.0303 - val_loss: 2.0181 - val_y1_output_loss: 0.5219 - val_y2_output_loss: 1.4962 - val_y1_output_root_mean_squared_error: 0.7224 - val_y2_output_root_mean_squared_error: 1.2232
# Epoch 101/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.2670 - y1_output_loss: 0.8773 - y2_output_loss: 2.3897 - y1_output_root_mean_squared_error: 0.9366 - y2_output_root_mean_squared_error: 1.5459 - val_loss: 2.5212 - val_y1_output_loss: 0.6197 - val_y2_output_loss: 1.9014 - val_y1_output_root_mean_squared_error: 0.7872 - val_y2_output_root_mean_squared_error: 1.3789
# Epoch 102/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.5159 - y1_output_loss: 0.5880 - y2_output_loss: 1.9278 - y1_output_root_mean_squared_error: 0.7668 - y2_output_root_mean_squared_error: 1.3885 - val_loss: 3.5058 - val_y1_output_loss: 0.5114 - val_y2_output_loss: 2.9944 - val_y1_output_root_mean_squared_error: 0.7151 - val_y2_output_root_mean_squared_error: 1.7304
# Epoch 103/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.9551 - y1_output_loss: 0.7374 - y2_output_loss: 2.2177 - y1_output_root_mean_squared_error: 0.8587 - y2_output_root_mean_squared_error: 1.4892 - val_loss: 2.4956 - val_y1_output_loss: 0.8125 - val_y2_output_loss: 1.6831 - val_y1_output_root_mean_squared_error: 0.9014 - val_y2_output_root_mean_squared_error: 1.2973
# Epoch 104/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.5523 - y1_output_loss: 0.9445 - y2_output_loss: 2.6078 - y1_output_root_mean_squared_error: 0.9718 - y2_output_root_mean_squared_error: 1.6149 - val_loss: 3.7880 - val_y1_output_loss: 1.0368 - val_y2_output_loss: 2.7513 - val_y1_output_root_mean_squared_error: 1.0182 - val_y2_output_root_mean_squared_error: 1.6587
# Epoch 105/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.5743 - y1_output_loss: 0.6616 - y2_output_loss: 1.9127 - y1_output_root_mean_squared_error: 0.8134 - y2_output_root_mean_squared_error: 1.3830 - val_loss: 1.9394 - val_y1_output_loss: 0.4173 - val_y2_output_loss: 1.5221 - val_y1_output_root_mean_squared_error: 0.6460 - val_y2_output_root_mean_squared_error: 1.2337
# Epoch 106/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.0841 - y1_output_loss: 0.5215 - y2_output_loss: 1.5626 - y1_output_root_mean_squared_error: 0.7221 - y2_output_root_mean_squared_error: 1.2500 - val_loss: 2.0437 - val_y1_output_loss: 0.4254 - val_y2_output_loss: 1.6183 - val_y1_output_root_mean_squared_error: 0.6522 - val_y2_output_root_mean_squared_error: 1.2721
# Epoch 107/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.1338 - y1_output_loss: 0.5326 - y2_output_loss: 1.6012 - y1_output_root_mean_squared_error: 0.7298 - y2_output_root_mean_squared_error: 1.2654 - val_loss: 6.8454 - val_y1_output_loss: 2.1369 - val_y2_output_loss: 4.7085 - val_y1_output_root_mean_squared_error: 1.4618 - val_y2_output_root_mean_squared_error: 2.1699
# Epoch 108/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.8871 - y1_output_loss: 0.9900 - y2_output_loss: 2.8972 - y1_output_root_mean_squared_error: 0.9950 - y2_output_root_mean_squared_error: 1.7021 - val_loss: 2.3188 - val_y1_output_loss: 0.6167 - val_y2_output_loss: 1.7021 - val_y1_output_root_mean_squared_error: 0.7853 - val_y2_output_root_mean_squared_error: 1.3046
# Epoch 109/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.6790 - y1_output_loss: 0.7077 - y2_output_loss: 1.9713 - y1_output_root_mean_squared_error: 0.8413 - y2_output_root_mean_squared_error: 1.4040 - val_loss: 2.4414 - val_y1_output_loss: 0.4785 - val_y2_output_loss: 1.9629 - val_y1_output_root_mean_squared_error: 0.6918 - val_y2_output_root_mean_squared_error: 1.4010
# Epoch 110/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.2716 - y1_output_loss: 0.8972 - y2_output_loss: 2.3744 - y1_output_root_mean_squared_error: 0.9472 - y2_output_root_mean_squared_error: 1.5409 - val_loss: 8.9108 - val_y1_output_loss: 2.1922 - val_y2_output_loss: 6.7186 - val_y1_output_root_mean_squared_error: 1.4806 - val_y2_output_root_mean_squared_error: 2.5920
# Epoch 111/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.4014 - y1_output_loss: 0.6141 - y2_output_loss: 1.7873 - y1_output_root_mean_squared_error: 0.7837 - y2_output_root_mean_squared_error: 1.3369 - val_loss: 3.2523 - val_y1_output_loss: 0.9988 - val_y2_output_loss: 2.2536 - val_y1_output_root_mean_squared_error: 0.9994 - val_y2_output_root_mean_squared_error: 1.5012
# Epoch 112/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.2522 - y1_output_loss: 0.5365 - y2_output_loss: 1.7157 - y1_output_root_mean_squared_error: 0.7324 - y2_output_root_mean_squared_error: 1.3099 - val_loss: 2.5285 - val_y1_output_loss: 0.6609 - val_y2_output_loss: 1.8676 - val_y1_output_root_mean_squared_error: 0.8130 - val_y2_output_root_mean_squared_error: 1.3666
# Epoch 113/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.7325 - y1_output_loss: 0.7553 - y2_output_loss: 1.9772 - y1_output_root_mean_squared_error: 0.8691 - y2_output_root_mean_squared_error: 1.4061 - val_loss: 3.9468 - val_y1_output_loss: 0.5204 - val_y2_output_loss: 3.4264 - val_y1_output_root_mean_squared_error: 0.7214 - val_y2_output_root_mean_squared_error: 1.8510
# Epoch 114/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.3432 - y1_output_loss: 2.0435 - y2_output_loss: 5.2997 - y1_output_root_mean_squared_error: 1.4295 - y2_output_root_mean_squared_error: 2.3021 - val_loss: 2.7524 - val_y1_output_loss: 0.7769 - val_y2_output_loss: 1.9755 - val_y1_output_root_mean_squared_error: 0.8814 - val_y2_output_root_mean_squared_error: 1.4055
# Epoch 115/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.5642 - y1_output_loss: 0.6892 - y2_output_loss: 1.8750 - y1_output_root_mean_squared_error: 0.8302 - y2_output_root_mean_squared_error: 1.3693 - val_loss: 2.7577 - val_y1_output_loss: 0.7490 - val_y2_output_loss: 2.0086 - val_y1_output_root_mean_squared_error: 0.8655 - val_y2_output_root_mean_squared_error: 1.4173
# Epoch 116/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.0054 - y1_output_loss: 0.4769 - y2_output_loss: 1.5285 - y1_output_root_mean_squared_error: 0.6905 - y2_output_root_mean_squared_error: 1.2363 - val_loss: 2.1620 - val_y1_output_loss: 0.4514 - val_y2_output_loss: 1.7106 - val_y1_output_root_mean_squared_error: 0.6718 - val_y2_output_root_mean_squared_error: 1.3079
# Epoch 117/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.5553 - y1_output_loss: 0.6464 - y2_output_loss: 1.9089 - y1_output_root_mean_squared_error: 0.8040 - y2_output_root_mean_squared_error: 1.3816 - val_loss: 2.5188 - val_y1_output_loss: 0.7244 - val_y2_output_loss: 1.7944 - val_y1_output_root_mean_squared_error: 0.8511 - val_y2_output_root_mean_squared_error: 1.3396
# Epoch 118/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0114 - y1_output_loss: 0.6136 - y2_output_loss: 2.3978 - y1_output_root_mean_squared_error: 0.7833 - y2_output_root_mean_squared_error: 1.5485 - val_loss: 2.0945 - val_y1_output_loss: 0.5227 - val_y2_output_loss: 1.5717 - val_y1_output_root_mean_squared_error: 0.7230 - val_y2_output_root_mean_squared_error: 1.2537
# Epoch 119/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.9795 - y1_output_loss: 0.4557 - y2_output_loss: 1.5238 - y1_output_root_mean_squared_error: 0.6750 - y2_output_root_mean_squared_error: 1.2344 - val_loss: 2.8871 - val_y1_output_loss: 1.0607 - val_y2_output_loss: 1.8263 - val_y1_output_root_mean_squared_error: 1.0299 - val_y2_output_root_mean_squared_error: 1.3514
# Epoch 120/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.8750 - y1_output_loss: 0.4821 - y2_output_loss: 1.3929 - y1_output_root_mean_squared_error: 0.6943 - y2_output_root_mean_squared_error: 1.1802 - val_loss: 6.2228 - val_y1_output_loss: 0.6540 - val_y2_output_loss: 5.5688 - val_y1_output_root_mean_squared_error: 0.8087 - val_y2_output_root_mean_squared_error: 2.3598
# Epoch 121/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.1055 - y1_output_loss: 0.7098 - y2_output_loss: 2.3957 - y1_output_root_mean_squared_error: 0.8425 - y2_output_root_mean_squared_error: 1.5478 - val_loss: 5.1591 - val_y1_output_loss: 1.0269 - val_y2_output_loss: 4.1322 - val_y1_output_root_mean_squared_error: 1.0134 - val_y2_output_root_mean_squared_error: 2.0328
# Epoch 122/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.4917 - y1_output_loss: 0.4888 - y2_output_loss: 2.0029 - y1_output_root_mean_squared_error: 0.6991 - y2_output_root_mean_squared_error: 1.4152 - val_loss: 2.1876 - val_y1_output_loss: 0.5738 - val_y2_output_loss: 1.6139 - val_y1_output_root_mean_squared_error: 0.7575 - val_y2_output_root_mean_squared_error: 1.2704
# Epoch 123/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5077 - y1_output_loss: 0.1424 - y2_output_loss: 0.3652 - y1_output_root_mean_squared_error: 0.3774 - y2_output_root_mean_squared_error: 0.6044 - val_loss: 0.8440 - val_y1_output_loss: 0.2056 - val_y2_output_loss: 0.6384 - val_y1_output_root_mean_squared_error: 0.4534 - val_y2_output_root_mean_squared_error: 0.7990
# Epoch 462/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4892 - y1_output_loss: 0.1698 - y2_output_loss: 0.3194 - y1_output_root_mean_squared_error: 0.4121 - y2_output_root_mean_squared_error: 0.5652 - val_loss: 1.1503 - val_y1_output_loss: 0.3049 - val_y2_output_loss: 0.8454 - val_y1_output_root_mean_squared_error: 0.5521 - val_y2_output_root_mean_squared_error: 0.9195
# Epoch 463/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3510 - y1_output_loss: 0.1255 - y2_output_loss: 0.2255 - y1_output_root_mean_squared_error: 0.3543 - y2_output_root_mean_squared_error: 0.4749 - val_loss: 0.8098 - val_y1_output_loss: 0.1808 - val_y2_output_loss: 0.6290 - val_y1_output_root_mean_squared_error: 0.4252 - val_y2_output_root_mean_squared_error: 0.7931
# Epoch 464/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5448 - y1_output_loss: 0.1458 - y2_output_loss: 0.3991 - y1_output_root_mean_squared_error: 0.3818 - y2_output_root_mean_squared_error: 0.6317 - val_loss: 0.7934 - val_y1_output_loss: 0.2122 - val_y2_output_loss: 0.5812 - val_y1_output_root_mean_squared_error: 0.4607 - val_y2_output_root_mean_squared_error: 0.7624
# Epoch 465/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4651 - y1_output_loss: 0.1455 - y2_output_loss: 0.3196 - y1_output_root_mean_squared_error: 0.3814 - y2_output_root_mean_squared_error: 0.5653 - val_loss: 0.7533 - val_y1_output_loss: 0.2097 - val_y2_output_loss: 0.5436 - val_y1_output_root_mean_squared_error: 0.4579 - val_y2_output_root_mean_squared_error: 0.7373
# Epoch 466/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4285 - y1_output_loss: 0.1271 - y2_output_loss: 0.3013 - y1_output_root_mean_squared_error: 0.3565 - y2_output_root_mean_squared_error: 0.5489 - val_loss: 0.9880 - val_y1_output_loss: 0.2214 - val_y2_output_loss: 0.7666 - val_y1_output_root_mean_squared_error: 0.4705 - val_y2_output_root_mean_squared_error: 0.8756
# Epoch 467/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4393 - y1_output_loss: 0.1277 - y2_output_loss: 0.3116 - y1_output_root_mean_squared_error: 0.3574 - y2_output_root_mean_squared_error: 0.5582 - val_loss: 0.8909 - val_y1_output_loss: 0.2582 - val_y2_output_loss: 0.6327 - val_y1_output_root_mean_squared_error: 0.5082 - val_y2_output_root_mean_squared_error: 0.7954
# Epoch 468/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4115 - y1_output_loss: 0.1355 - y2_output_loss: 0.2760 - y1_output_root_mean_squared_error: 0.3682 - y2_output_root_mean_squared_error: 0.5253 - val_loss: 0.7836 - val_y1_output_loss: 0.2050 - val_y2_output_loss: 0.5785 - val_y1_output_root_mean_squared_error: 0.4528 - val_y2_output_root_mean_squared_error: 0.7606
# Epoch 469/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3891 - y1_output_loss: 0.1283 - y2_output_loss: 0.2608 - y1_output_root_mean_squared_error: 0.3581 - y2_output_root_mean_squared_error: 0.5107 - val_loss: 2.1659 - val_y1_output_loss: 0.3255 - val_y2_output_loss: 1.8404 - val_y1_output_root_mean_squared_error: 0.5705 - val_y2_output_root_mean_squared_error: 1.3566
# Epoch 470/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6921 - y1_output_loss: 0.1885 - y2_output_loss: 0.5036 - y1_output_root_mean_squared_error: 0.4341 - y2_output_root_mean_squared_error: 0.7097 - val_loss: 1.3504 - val_y1_output_loss: 0.3153 - val_y2_output_loss: 1.0351 - val_y1_output_root_mean_squared_error: 0.5615 - val_y2_output_root_mean_squared_error: 1.0174
# Epoch 471/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3871 - y1_output_loss: 0.1321 - y2_output_loss: 0.2550 - y1_output_root_mean_squared_error: 0.3635 - y2_output_root_mean_squared_error: 0.5050 - val_loss: 0.7439 - val_y1_output_loss: 0.1773 - val_y2_output_loss: 0.5666 - val_y1_output_root_mean_squared_error: 0.4211 - val_y2_output_root_mean_squared_error: 0.7527
# Epoch 472/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4108 - y1_output_loss: 0.1388 - y2_output_loss: 0.2720 - y1_output_root_mean_squared_error: 0.3725 - y2_output_root_mean_squared_error: 0.5216 - val_loss: 3.8930 - val_y1_output_loss: 1.2930 - val_y2_output_loss: 2.6000 - val_y1_output_root_mean_squared_error: 1.1371 - val_y2_output_root_mean_squared_error: 1.6125
# Epoch 473/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5247 - y1_output_loss: 0.1811 - y2_output_loss: 0.3436 - y1_output_root_mean_squared_error: 0.4255 - y2_output_root_mean_squared_error: 0.5862 - val_loss: 1.2974 - val_y1_output_loss: 0.2006 - val_y2_output_loss: 1.0967 - val_y1_output_root_mean_squared_error: 0.4479 - val_y2_output_root_mean_squared_error: 1.0473
# Epoch 474/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3718 - y1_output_loss: 0.1214 - y2_output_loss: 0.2504 - y1_output_root_mean_squared_error: 0.3484 - y2_output_root_mean_squared_error: 0.5004 - val_loss: 0.6816 - val_y1_output_loss: 0.1819 - val_y2_output_loss: 0.4997 - val_y1_output_root_mean_squared_error: 0.4265 - val_y2_output_root_mean_squared_error: 0.7069
# Epoch 475/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3511 - y1_output_loss: 0.1122 - y2_output_loss: 0.2389 - y1_output_root_mean_squared_error: 0.3349 - y2_output_root_mean_squared_error: 0.4888 - val_loss: 0.7500 - val_y1_output_loss: 0.1822 - val_y2_output_loss: 0.5678 - val_y1_output_root_mean_squared_error: 0.4268 - val_y2_output_root_mean_squared_error: 0.7536
# Epoch 476/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5328 - y1_output_loss: 0.1661 - y2_output_loss: 0.3667 - y1_output_root_mean_squared_error: 0.4075 - y2_output_root_mean_squared_error: 0.6056 - val_loss: 0.6508 - val_y1_output_loss: 0.1764 - val_y2_output_loss: 0.4744 - val_y1_output_root_mean_squared_error: 0.4200 - val_y2_output_root_mean_squared_error: 0.6888
# Epoch 477/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4123 - y1_output_loss: 0.1315 - y2_output_loss: 0.2809 - y1_output_root_mean_squared_error: 0.3626 - y2_output_root_mean_squared_error: 0.5300 - val_loss: 0.9153 - val_y1_output_loss: 0.2401 - val_y2_output_loss: 0.6752 - val_y1_output_root_mean_squared_error: 0.4899 - val_y2_output_root_mean_squared_error: 0.8217
# Epoch 478/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5363 - y1_output_loss: 0.1616 - y2_output_loss: 0.3747 - y1_output_root_mean_squared_error: 0.4019 - y2_output_root_mean_squared_error: 0.6121 - val_loss: 0.7600 - val_y1_output_loss: 0.2610 - val_y2_output_loss: 0.4990 - val_y1_output_root_mean_squared_error: 0.5109 - val_y2_output_root_mean_squared_error: 0.7064
# Epoch 479/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4374 - y1_output_loss: 0.1325 - y2_output_loss: 0.3050 - y1_output_root_mean_squared_error: 0.3639 - y2_output_root_mean_squared_error: 0.5523 - val_loss: 0.7701 - val_y1_output_loss: 0.2075 - val_y2_output_loss: 0.5626 - val_y1_output_root_mean_squared_error: 0.4555 - val_y2_output_root_mean_squared_error: 0.7501
# Epoch 480/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4928 - y1_output_loss: 0.1606 - y2_output_loss: 0.3322 - y1_output_root_mean_squared_error: 0.4007 - y2_output_root_mean_squared_error: 0.5764 - val_loss: 0.7680 - val_y1_output_loss: 0.1853 - val_y2_output_loss: 0.5827 - val_y1_output_root_mean_squared_error: 0.4304 - val_y2_output_root_mean_squared_error: 0.7634
# Epoch 481/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4389 - y1_output_loss: 0.1261 - y2_output_loss: 0.3128 - y1_output_root_mean_squared_error: 0.3551 - y2_output_root_mean_squared_error: 0.5593 - val_loss: 0.6795 - val_y1_output_loss: 0.1739 - val_y2_output_loss: 0.5056 - val_y1_output_root_mean_squared_error: 0.4170 - val_y2_output_root_mean_squared_error: 0.7111
# Epoch 482/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5280 - y1_output_loss: 0.1702 - y2_output_loss: 0.3578 - y1_output_root_mean_squared_error: 0.4125 - y2_output_root_mean_squared_error: 0.5982 - val_loss: 1.2156 - val_y1_output_loss: 0.2595 - val_y2_output_loss: 0.9561 - val_y1_output_root_mean_squared_error: 0.5094 - val_y2_output_root_mean_squared_error: 0.9778
# Epoch 483/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5662 - y1_output_loss: 0.1477 - y2_output_loss: 0.4185 - y1_output_root_mean_squared_error: 0.3843 - y2_output_root_mean_squared_error: 0.6469 - val_loss: 0.7164 - val_y1_output_loss: 0.1906 - val_y2_output_loss: 0.5258 - val_y1_output_root_mean_squared_error: 0.4365 - val_y2_output_root_mean_squared_error: 0.7251
# Epoch 484/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5567 - y1_output_loss: 0.1410 - y2_output_loss: 0.4157 - y1_output_root_mean_squared_error: 0.3755 - y2_output_root_mean_squared_error: 0.6448 - val_loss: 0.8217 - val_y1_output_loss: 0.1771 - val_y2_output_loss: 0.6446 - val_y1_output_root_mean_squared_error: 0.4209 - val_y2_output_root_mean_squared_error: 0.8029
# Epoch 485/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3445 - y1_output_loss: 0.1083 - y2_output_loss: 0.2362 - y1_output_root_mean_squared_error: 0.3291 - y2_output_root_mean_squared_error: 0.4860 - val_loss: 0.6793 - val_y1_output_loss: 0.1819 - val_y2_output_loss: 0.4974 - val_y1_output_root_mean_squared_error: 0.4265 - val_y2_output_root_mean_squared_error: 0.7053
# Epoch 486/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3863 - y1_output_loss: 0.1260 - y2_output_loss: 0.2603 - y1_output_root_mean_squared_error: 0.3549 - y2_output_root_mean_squared_error: 0.5102 - val_loss: 0.7661 - val_y1_output_loss: 0.1958 - val_y2_output_loss: 0.5704 - val_y1_output_root_mean_squared_error: 0.4425 - val_y2_output_root_mean_squared_error: 0.7552
# Epoch 487/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4261 - y1_output_loss: 0.1335 - y2_output_loss: 0.2925 - y1_output_root_mean_squared_error: 0.3654 - y2_output_root_mean_squared_error: 0.5409 - val_loss: 0.9268 - val_y1_output_loss: 0.2309 - val_y2_output_loss: 0.6959 - val_y1_output_root_mean_squared_error: 0.4805 - val_y2_output_root_mean_squared_error: 0.8342
# Epoch 488/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8656 - y1_output_loss: 0.2152 - y2_output_loss: 0.6504 - y1_output_root_mean_squared_error: 0.4639 - y2_output_root_mean_squared_error: 0.8065 - val_loss: 1.8675 - val_y1_output_loss: 0.1992 - val_y2_output_loss: 1.6683 - val_y1_output_root_mean_squared_error: 0.4463 - val_y2_output_root_mean_squared_error: 1.2916
# Epoch 489/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4916 - y1_output_loss: 0.1454 - y2_output_loss: 0.3462 - y1_output_root_mean_squared_error: 0.3814 - y2_output_root_mean_squared_error: 0.5884 - val_loss: 0.8347 - val_y1_output_loss: 0.2040 - val_y2_output_loss: 0.6308 - val_y1_output_root_mean_squared_error: 0.4516 - val_y2_output_root_mean_squared_error: 0.7942
# Epoch 490/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6160 - y1_output_loss: 0.1894 - y2_output_loss: 0.4265 - y1_output_root_mean_squared_error: 0.4352 - y2_output_root_mean_squared_error: 0.6531 - val_loss: 0.7333 - val_y1_output_loss: 0.2403 - val_y2_output_loss: 0.4930 - val_y1_output_root_mean_squared_error: 0.4902 - val_y2_output_root_mean_squared_error: 0.7021
# Epoch 491/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4391 - y1_output_loss: 0.1307 - y2_output_loss: 0.3084 - y1_output_root_mean_squared_error: 0.3616 - y2_output_root_mean_squared_error: 0.5553 - val_loss: 0.7752 - val_y1_output_loss: 0.1828 - val_y2_output_loss: 0.5924 - val_y1_output_root_mean_squared_error: 0.4275 - val_y2_output_root_mean_squared_error: 0.7697
# Epoch 492/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.1871 - y1_output_loss: 0.2172 - y2_output_loss: 0.9700 - y1_output_root_mean_squared_error: 0.4660 - y2_output_root_mean_squared_error: 0.9849 - val_loss: 5.4171 - val_y1_output_loss: 1.6031 - val_y2_output_loss: 3.8141 - val_y1_output_root_mean_squared_error: 1.2661 - val_y2_output_root_mean_squared_error: 1.9530
# Epoch 493/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5658 - y1_output_loss: 0.1756 - y2_output_loss: 0.3902 - y1_output_root_mean_squared_error: 0.4190 - y2_output_root_mean_squared_error: 0.6247 - val_loss: 0.7833 - val_y1_output_loss: 0.1788 - val_y2_output_loss: 0.6044 - val_y1_output_root_mean_squared_error: 0.4229 - val_y2_output_root_mean_squared_error: 0.7775
# Epoch 494/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3746 - y1_output_loss: 0.1295 - y2_output_loss: 0.2450 - y1_output_root_mean_squared_error: 0.3599 - y2_output_root_mean_squared_error: 0.4950 - val_loss: 1.1031 - val_y1_output_loss: 0.2297 - val_y2_output_loss: 0.8735 - val_y1_output_root_mean_squared_error: 0.4792 - val_y2_output_root_mean_squared_error: 0.9346
# Epoch 495/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3837 - y1_output_loss: 0.1270 - y2_output_loss: 0.2566 - y1_output_root_mean_squared_error: 0.3564 - y2_output_root_mean_squared_error: 0.5066 - val_loss: 0.6994 - val_y1_output_loss: 0.2024 - val_y2_output_loss: 0.4970 - val_y1_output_root_mean_squared_error: 0.4499 - val_y2_output_root_mean_squared_error: 0.7050
# Epoch 496/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6655 - y1_output_loss: 0.1717 - y2_output_loss: 0.4938 - y1_output_root_mean_squared_error: 0.4144 - y2_output_root_mean_squared_error: 0.7027 - val_loss: 1.1043 - val_y1_output_loss: 0.4689 - val_y2_output_loss: 0.6353 - val_y1_output_root_mean_squared_error: 0.6848 - val_y2_output_root_mean_squared_error: 0.7971
# Epoch 497/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3385 - y1_output_loss: 0.1282 - y2_output_loss: 0.2103 - y1_output_root_mean_squared_error: 0.3581 - y2_output_root_mean_squared_error: 0.4586 - val_loss: 0.7208 - val_y1_output_loss: 0.1777 - val_y2_output_loss: 0.5431 - val_y1_output_root_mean_squared_error: 0.4215 - val_y2_output_root_mean_squared_error: 0.7370
# Epoch 498/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5185 - y1_output_loss: 0.1698 - y2_output_loss: 0.3487 - y1_output_root_mean_squared_error: 0.4121 - y2_output_root_mean_squared_error: 0.5905 - val_loss: 4.7387 - val_y1_output_loss: 0.7700 - val_y2_output_loss: 3.9687 - val_y1_output_root_mean_squared_error: 0.8775 - val_y2_output_root_mean_squared_error: 1.9922
# Epoch 499/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8464 - y1_output_loss: 0.1892 - y2_output_loss: 0.6572 - y1_output_root_mean_squared_error: 0.4350 - y2_output_root_mean_squared_error: 0.8107 - val_loss: 0.9829 - val_y1_output_loss: 0.2224 - val_y2_output_loss: 0.7605 - val_y1_output_root_mean_squared_error: 0.4716 - val_y2_output_root_mean_squared_error: 0.8721
# Epoch 500/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4221 - y1_output_loss: 0.1344 - y2_output_loss: 0.2876 - y1_output_root_mean_squared_error: 0.3667 - y2_output_root_mean_squared_error: 0.5363 - val_loss: 1.0011 - val_y1_output_loss: 0.2509 - val_y2_output_loss: 0.7502 - val_y1_output_root_mean_squared_error: 0.5009 - val_y2_output_root_mean_squared_error: 0.8661

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 1.0011 - y1_output_loss: 0.2509 - y2_output_loss: 0.7502 - y1_output_root_mean_squared_error: 0.5009 - y2_output_root_mean_squared_error: 0.8661
# Loss = 1.0011316537857056, Y1_loss = 0.2509223222732544, Y1_mse = 0.5009214878082275, Y2_loss = 0.7502093315124512, Y2_mse = 0.8661462664604187

# %%
type(Y_pred)
# Out:
# list

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
